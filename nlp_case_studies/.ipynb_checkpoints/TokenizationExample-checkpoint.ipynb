# %%
corpus="""Hello Welcome, to my Deep Learning Journey.
Plz explore my journey with my Github repository."""

# %%
print(corpus)
# Out:
# Hello Welcome, to my Deep Learning Journey.
# Plz explore my journey with my Github repository.

# %%
import nltk

nltk.download('punkt_tab')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\NIRAJ\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\NIRAJ\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
#Tokenization --> Converting Paragraphs into sentence.
from nltk.tokenize import sent_tokenize

# %%
documents =sent_tokenize(corpus)

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to my Deep Learning Journey.
# Plz explore my journey with my Github repository.

# %%
##Tokenization
##Sentence--> Words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'my',
#  'Deep',
#  'Learning',
#  'Journey',
#  '.',
#  'Plz',
#  'explore',
#  'my',
#  'journey',
#  'with',
#  'my',
#  'Github',
#  'repository',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'my', 'Deep', 'Learning', 'Journey', '.']
# ['Plz', 'explore', 'my', 'journey', 'with', 'my', 'Github', 'repository', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'my',
#  'Deep',
#  'Learning',
#  'Journey.',
#  'Plz',
#  'explore',
#  'my',
#  'journey',
#  'with',
#  'my',
#  'Github',
#  'repository',
#  '.']
